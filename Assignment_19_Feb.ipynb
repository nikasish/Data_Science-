# %% [markdown]
# ### Assignment 19 Feb

# %% [markdown]
# ### Q1

# %% [markdown]
# #### Flask Framework is python framework written in python, it is used to developing the web pages or applications.
# #### Flask framework is more independent, flexible, and simple to use so that evry developer is likely used flask.

# %% [markdown]
# ### Q2

# %% [markdown]
# ![image.png](attachment:a981251f-12b7-4553-8467-3505079f1440.png)

# %% [markdown]
# ![image.png](attachment:77bb6883-9366-4a8e-8407-d7f109e5bc51.png)

# %% [markdown]
# ### Q3

# %% [markdown]
# #### App routing is a technique in flask and  it is used to mapping the url in the applications to perfom their tasks. it is a function to perform their associate work.

# %% [markdown]
# ### Q4

# %% [markdown]
# ![image.png](attachment:962fde55-dc55-411a-a3fa-22fb3dc4bfad.png)

# %% [markdown]
# ![image.png](attachment:8cc9aec1-313a-4665-847b-0080590e7b87.png)

# %% [markdown]
# ![image.png](attachment:ce6e74fe-fee4-4a8e-87aa-e668f329dd4a.png)

# %% [markdown]
# ### Q5

# %% [markdown]
# #### url_for is used to building the url in flask.

# %% [markdown]
# ![image.png](attachment:6a4e373f-eb25-492f-bfaf-dd83fe6d38ed.png)

# %% [markdown]
# ![image.png](attachment:0e573fc2-c7dc-4b4d-ae32-5f7ac0daf710.png)
