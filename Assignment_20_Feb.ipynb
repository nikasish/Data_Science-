# %% [markdown]
# ### Assignment 20 Feb

# %% [markdown]
# ### Q1

# %% [markdown]
# #### Get Method iis used the send the data from a specific location to another by the url here we can see when we send the data by the GET method the data will visible in the url section also we can say that this method is not secure in the security purpose where as POST have done the same work but in security purpose it is more secure, it done not show data in the url section for that it more secure rather then GET. Get method send the data in the form of value wise but post send the data body wise so that it is better than GET security purpose. where as we can say POST method better than GET method.

# %% [markdown]
# ### Q2

# %% [markdown]
# #### Request is an object in flask. request object is used to catch the all incomming requests and perform their operation as per the request requirements. we can say request work as a middleman for the pre define functions and client.

# %% [markdown]
# ### Q3

# %% [markdown]
# #### redirect is a method/function in python flask. it is used to define the specifid location of a function for the respective url. means we can say redirect help to reach out the spefic function on selecting url.

# %% [markdown]
# #### exaple:-

# %% [markdown]
# ![image.png](attachment:b5dcfa1e-c5b2-4ff0-a790-02ea15e67db0.png)

# %% [markdown]
# ### Q4

# %% [markdown]
# #### template ia a folder in flask which can store the html, css, javascript files for output the UI. when any client request for any operation this folder can communicate flask function with respective protocols and return as a output from the template folder.

# %% [markdown]
# #### render_template is used to produce the final data for the specific url.

# %% [markdown]
# ### Q5

# %% [markdown]
# ![image.png](attachment:973d1faa-eb84-4f76-8102-ae6c807e00dd.png)

# %% [markdown]
# ![image.png](attachment:59e2b16c-25c9-4d12-af22-dc529ac437b3.png)
